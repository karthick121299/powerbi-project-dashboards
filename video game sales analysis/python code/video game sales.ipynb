# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import radians, sin, cos, asin, sqrt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.metrics import r2_score

# %%
df=pd.read_csv(r"C:\Users\karth\Downloads\Video+Game+Sales\vgchartz-2024.csv")
df
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# img                 0
# title               0
# console             0
# genre               0
# publisher           0
# developer          17
# critic_score    57338
# total_sales     45094
# na_sales        51379
# jp_sales        57290
# pal_sales       51192
# other_sales     48888
# release_date     7051
# last_update     46137
# dtype: int64

# %%
df=df.drop(["img","last_update"], axis= 1)

# %%
df
# Out:
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# 4             Call of Duty: Black Ops 3     PS4       Shooter
# ...                                 ...     ...           ...
# 64011             XBlaze Lost: Memories      PC  Visual Novel
# 64012                      Yoru, Tomosu     PS4  Visual Novel
# 64013                      Yoru, Tomosu      NS  Visual Novel
# 64014   Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
# 64015  Yurukill: The Calumniation Games     PS4  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# ...

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df = df.dropna(subset=["release_date"])

# %%
df
# Out:
#                                  title console         genre  \
# 0                   Grand Theft Auto V     PS3        Action
# 1                   Grand Theft Auto V     PS4        Action
# 2          Grand Theft Auto: Vice City     PS2        Action
# 3                   Grand Theft Auto V    X360        Action
# 4            Call of Duty: Black Ops 3     PS4       Shooter
# ...                                ...     ...           ...
# 64010               World End Syndrome     PS4  Visual Novel
# 64011            XBlaze Lost: Memories      PC  Visual Novel
# 64012                     Yoru, Tomosu     PS4  Visual Novel
# 64013                     Yoru, Tomosu      NS  Visual Novel
# 64014  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# ...

# %%
df.describe()
# Out:
#        critic_score   total_sales      na_sales     jp_sales     pal_sales  \
# count   6634.000000  18832.000000  12620.000000  6688.000000  12776.000000
# mean       7.220546      0.350431      0.265036     0.102421      0.149862
# std        1.457602      0.809039      0.495046     0.169141      0.393217
# min        1.000000      0.000000      0.000000     0.000000      0.000000
# 25%        6.400000      0.030000      0.050000     0.020000      0.010000
# 50%        7.500000      0.120000      0.120000     0.040000      0.040000
# 75%        8.300000      0.350000      0.280000     0.120000      0.140000
# max       10.000000     20.320000      9.760000     2.130000      9.850000
#
#         other_sales
# count  15071.000000
# mean       0.043163
# std        0.126838
# min        0.000000
# 25%        0.000000
# 50%        0.010000
# 75%        0.030000
# max        3.120000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56965 entries, 0 to 64014
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         56965 non-null  object
#  1   console       56965 non-null  object
#  2   genre         56965 non-null  object
#  3   publisher     56965 non-null  object
#  4   developer     56954 non-null  object
#  5   critic_score  6634 non-null   float64
#  6   total_sales   18832 non-null  float64
#  7   na_sales      12620 non-null  float64
#  8   jp_sales      6688 non-null   float64
#  9   pal_sales     12776 non-null  float64
#  10  other_sales   15071 non-null  float64
#  11  release_date  56965 non-null  object
# dtypes: float64(6), object(6)
# memory usage: 5.6+ MB

# %%
df["console"].unique()
# Out:
# array(['PS3', 'PS4', 'PS2', 'X360', 'XOne', 'PC', 'PSP', 'Wii', 'PS',
#        'DS', '2600', 'GBA', 'NES', 'XB', 'PSN', 'GEN', 'PSV', 'DC', 'N64',
#        'SAT', 'SNES', 'GBC', 'GC', 'NS', '3DS', 'GB', 'WiiU', 'WS', 'VC',
#        'NG', 'WW', 'SCD', 'PCE', 'XBL', '3DO', 'GG', 'OSX', 'Mob', 'PCFX',
#        'Series', 'All', 'iOS', '5200', 'And', 'DSiW', 'Lynx', 'Linux',
#        'MS', 'ZXS', 'ACPC', 'Amig', '7800', 'AJ', 'WinP', 'VB', 'Ouya',
#        'NGage', 'AST', 'MSD', 'S32X', 'Int', 'XS', 'PS5', 'CV', 'OR',
#        'C128', 'CDi', 'DSi', 'Arc', 'C64', 'BRW', 'FMT', 'MSX', 'GIZ',
#        'ApII', 'Aco', 'BBCM', 'TG16', 'CD32'], dtype=object)

# %%
df[['total_sales', 'na_sales', 'jp_sales', 'pal_sales', 'other_sales']] = \
df[['total_sales', 'na_sales', 'jp_sales', 'pal_sales', 'other_sales']].fillna(0)
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_33868\2791628891.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['total_sales', 'na_sales', 'jp_sales', 'pal_sales', 'other_sales']] = \

# %%
df
# Out:
#                                  title console         genre  \
# 0                   Grand Theft Auto V     PS3        Action
# 1                   Grand Theft Auto V     PS4        Action
# 2          Grand Theft Auto: Vice City     PS2        Action
# 3                   Grand Theft Auto V    X360        Action
# 4            Call of Duty: Black Ops 3     PS4       Shooter
# ...                                ...     ...           ...
# 64010               World End Syndrome     PS4  Visual Novel
# 64011            XBlaze Lost: Memories      PC  Visual Novel
# 64012                     Yoru, Tomosu     PS4  Visual Novel
# 64013                     Yoru, Tomosu      NS  Visual Novel
# 64014  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                   publisher             developer  critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North           9.4        20.32
# ...

# %%
df['critic_score']=df['critic_score'].fillna('NA')
# Out:
# C:\Users\karth\AppData\Local\Temp\ipykernel_33868\1822379149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['critic_score']=df['critic_score'].fillna('NA')

# %%
df
# Out:
#                                  title console         genre  \
# 0                   Grand Theft Auto V     PS3        Action
# 1                   Grand Theft Auto V     PS4        Action
# 2          Grand Theft Auto: Vice City     PS2        Action
# 3                   Grand Theft Auto V    X360        Action
# 4            Call of Duty: Black Ops 3     PS4       Shooter
# ...                                ...     ...           ...
# 64010               World End Syndrome     PS4  Visual Novel
# 64011            XBlaze Lost: Memories      PC  Visual Novel
# 64012                     Yoru, Tomosu     PS4  Visual Novel
# 64013                     Yoru, Tomosu      NS  Visual Novel
# 64014  Yunohana SpRING! ~Mellow Times~      NS  Visual Novel
#
#                   publisher             developer critic_score  total_sales  \
# 0            Rockstar Games        Rockstar North          9.4        20.32
# 1            Rockstar Games        Rockstar North          9.7        19.39
# ...

# %%
df = df[df['console'] != 'All']

# %%
df["console"].unique()
# Out:
# array(['PS3', 'PS4', 'PS2', 'X360', 'XOne', 'PC', 'PSP', 'Wii', 'PS',
#        'DS', '2600', 'GBA', 'NES', 'XB', 'PSN', 'GEN', 'PSV', 'DC', 'N64',
#        'SAT', 'SNES', 'GBC', 'GC', 'NS', '3DS', 'GB', 'WiiU', 'WS', 'VC',
#        'NG', 'WW', 'SCD', 'PCE', 'XBL', '3DO', 'GG', 'OSX', 'Mob', 'PCFX',
#        'Series', 'iOS', '5200', 'And', 'DSiW', 'Lynx', 'Linux', 'MS',
#        'ZXS', 'ACPC', 'Amig', '7800', 'AJ', 'WinP', 'VB', 'Ouya', 'NGage',
#        'AST', 'MSD', 'S32X', 'Int', 'XS', 'PS5', 'CV', 'OR', 'C128',
#        'CDi', 'DSi', 'Arc', 'C64', 'BRW', 'FMT', 'MSX', 'GIZ', 'ApII',
#        'Aco', 'BBCM', 'TG16', 'CD32'], dtype=object)

# %%
df.to_csv("video game analysis.csv", index=False)
