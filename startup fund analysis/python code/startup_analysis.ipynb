# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
df= pd.read_csv(r"C:\analysis\pr a 2\kickstarter_projects.csv")

# %%
df.describe()
# Out:
#                  ID          Goal       Pledged        Backers
# count  3.748530e+05  3.748530e+05  3.748530e+05  374853.000000
# mean   1.074656e+09  4.586378e+04  9.121073e+03     106.690359
# std    6.191377e+08  1.158778e+06  9.132054e+04     911.718520
# min    5.971000e+03  0.000000e+00  0.000000e+00       0.000000
# 25%    5.380728e+08  2.000000e+03  3.100000e+01       2.000000
# 50%    1.075300e+09  5.500000e+03  6.250000e+02      12.000000
# 75%    1.610149e+09  1.600000e+04  4.051000e+03      57.000000
# max    2.147476e+09  1.663614e+08  2.033899e+07  219382.000000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 374853 entries, 0 to 374852
# Data columns (total 11 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ID           374853 non-null  int64
#  1   Name         374853 non-null  str
#  2   Category     374853 non-null  str
#  3   Subcategory  374853 non-null  str
#  4   Country      374853 non-null  str
#  5   Launched     374853 non-null  str
#  6   Deadline     374853 non-null  str
#  7   Goal         374853 non-null  int64
#  8   Pledged      374853 non-null  int64
#  9   Backers      374853 non-null  int64
#  10  State        374853 non-null  str
# dtypes: int64(4), str(7)
# memory usage: 67.4 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Category       0
# Subcategory    0
# Country        0
# Launched       0
# Deadline       0
# Goal           0
# Pledged        0
# Backers        0
# State          0
# dtype: int64

# %%
df
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country             Launched  \
# ...

# %%
df["Launched"] = pd.to_datetime(df["Launched"])

# %%
df["Deadline"] = pd.to_datetime(df["Deadline"])

# %%
df["launched_date"]=df["Launched"].dt.date
df["Launched_time"]=df["Launched"].dt.time

# %%
df.describe(include='all')
for i in df.columns:
    print('\n===============(',i,')===============\n')
    print(df[i].unique())
# Out:
# ===============( ID )===============
#
# [1860890148  709707365 1703704063 ... 2106246194 1830173355 1339173863]
#
# ===============( Name )===============
#
# <ArrowStringArray>
# [                 'Grace Jones Does Not Give A F$#% T-Shirt (limited Edition) ',
#                                                'CRYSTAL ANTLERS UNTITLED MOVIE',
#                                                           'drawing for dollars',
#                                                  'Offline Wikipedia iPhone app',
#                                                                    'Pantshirts',
#                                                       'New York Makes a Book!!',
#                                                'Web Site for Short Horror Film',
#                                                'Help me write my second novel.',
#                                                     'Produce a Play (Canceled)',
# ...

# %%
df["State"]=df["State"].replace({'Canceled':'Failed','Suspended':'Failed'})

# %%
df["State"].unique()
# Out:
# <ArrowStringArray>
# ['Failed', 'Successful', 'Live']
# Length: 3, dtype: str

# %%
df
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country            Launched  \
# ...

# %%
df = df.drop(columns =["Launched"])

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Category', 'Subcategory', 'Country', 'Deadline', 'Goal',
#        'Pledged', 'Backers', 'State', 'launched_date', 'Launched_time'],
#       dtype='str')

# %%
df = df.loc[:,['ID', 'Name', 'Category', 'Subcategory', 'Country','launched_date', 'Launched_time', 'Deadline', 'Goal','Pledged', 'Backers', 'State']]

# %%
df
# Out:
#                 ID                                               Name  \
# 0       1860890148  Grace Jones Does Not Give A F$#% T-Shirt (limi...
# 1        709707365                     CRYSTAL ANTLERS UNTITLED MOVIE
# 2       1703704063                                drawing for dollars
# 3           727286                       Offline Wikipedia iPhone app
# 4       1622952265                                         Pantshirts
# ...            ...                                                ...
# 374848  1486845240                  Americas Got Talent - Serious MAK
# 374849   974738310  EVO Planner: The World's First Personalized Fl...
# 374850  2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 374851  1830173355                                Digital Dagger Coin
# 374852  1339173863                              Spirits of the Forest
#
#             Category     Subcategory        Country launched_date  \
# ...

# %%
df.to_csv("startup_analysis.csv", index=False)
